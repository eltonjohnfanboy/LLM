# %%
# !nvidia-smi
# Out:
# Sun Jun  2 17:09:31 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# Check for cuda availability
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Install the necessary libraries

# %%
# !pip install -q transformers[torch] datasets
# !pip install -q bitsandbytes trl peft
# !pip install flash-attn --no-build-isolation
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 56.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 30.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 30.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 15.8 MB/s eta 0:00:00
# Collecting flash-attn
#   Downloading flash_attn-2.5.9.post1.tar.gz (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 30.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash-attn) (2.3.0+cu121)
# Collecting einops (from flash-attn)
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash-attn) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash-attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash-attn) (1.3.0)
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.5.9.post1-cp310-cp310-linux_x86_64.whl size=120889689 sha256=5022ba11d48bf74926da9c16260f4ea2b9bb7f4e29bdb4bd6e1383ad1c55d16f
#   Stored in directory: /root/.cache/pip/wheels/cc/ad/f6/7ccf0238790d6346e9fe622923a76ec218e890d356b9a2754a
# Successfully built flash-attn
# Installing collected packages: einops, flash-attn
# Successfully installed einops-0.8.0 flash-attn-2.5.9.post1

# %% [markdown]
# ### Load Dataset

# %%
from datasets import load_dataset

raw_datasets = load_dataset("HuggingFaceH4/ultrachat_200k")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/4.44k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/244M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/244M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/244M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/81.2M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/244M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/243M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/243M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/80.4M [00:00<?, ?B/s]
# Generating train_sft split:   0%|          | 0/207865 [00:00<?, ? examples/s]
# Generating test_sft split:   0%|          | 0/23110 [00:00<?, ? examples/s]
# Generating train_gen split:   0%|          | 0/256032 [00:00<?, ? examples/s]
# Generating test_gen split:   0%|          | 0/28304 [00:00<?, ? examples/s]

# %%
from datasets import DatasetDict

# Scale the data once the model starts working
indices = range(0, 100)

dataset_dict = {"train": raw_datasets["train_sft"].select(indices),
                "test": raw_datasets["test_sft"].select(indices)}
raw_datasets = DatasetDict(dataset_dict)

# %% [markdown]
# ### Load Tokenizer

# %%
# Pass HF token to acces to the model
from huggingface_hub import login
login(token="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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoTokenizer

model_id = 'mistralai/Mistral-7B-v0.1'
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %%
if tokenizer.pad_token_id is None:
  tokenizer.pad_token_id = tokenizer.eos_token_id

if tokenizer.model_max_length > 100_000:
  tokenizer.model_max_length = 2048

DEFAULT_CHAT_TEMPLATE = "{% for message in messages %}\n{% if message['role'] == 'user' %}\n{{ '<|user|>\n' + message['content'] + eos_token }}\n{% elif message['role'] == 'system' %}\n{{ '<|system|>\n' + message['content'] + eos_token }}\n{% elif message['role'] == 'assistant' %}\n{{ '<|assistant|>\n'  + message['content'] + eos_token }}\n{% endif %}\n{% if loop.last and add_generation_prompt %}\n{{ '<|assistant|>' }}\n{% endif %}\n{% endfor %}"
tokenizer.chat_template = DEFAULT_CHAT_TEMPLATE

# %% [markdown]
# ### Apply chat template to all our prompts/inputs

# %%
import re
import random
from multiprocessing import cpu_count

def apply_chat_template(example, tokenizer):
    messages = example["messages"]
    # We add an empty system message if there is none
    if messages[0]["role"] != "system":
        messages.insert(0, {"role": "system", "content": ""})
    example["text"] = tokenizer.apply_chat_template(messages, tokenize=False)

    return example

column_names = list(raw_datasets["train"].features)
raw_datasets = raw_datasets.map(apply_chat_template,
                                num_proc=cpu_count(),
                                fn_kwargs={"tokenizer": tokenizer},
                                remove_columns=column_names,
                                desc="Applying chat template",)

# create the splits
train_dataset = raw_datasets["train"]
eval_dataset = raw_datasets["test"]

for index in random.sample(range(len(raw_datasets["train"])), 3):
  print(f"Sample {index} of the processed training set:\n\n{raw_datasets['train'][index]['text']}")
# Out:
# Applying chat template (num_proc=2):   0%|          | 0/100 [00:00<?, ? examples/s]
# Applying chat template (num_proc=2):   0%|          | 0/100 [00:00<?, ? examples/s]
# Sample 52 of the processed training set:
#
# <|system|>
# </s>
# <|user|>
# Stitching headlights through the scene.
# today it’s pushing orange through a sieve of suffering grey.
# So that’s two in a row which, though it doesn’t constitute a commitment of any sort from the writer, demonstrates at least some ability to follow through.
# Today I woke William just after 6, to get ready for school, and then sat down to write this poem. He dressed and ate, and then came over with his toothbrush in his mouth, and looked at the sunrise and said "Wooglw!".
# I could write a poem about the view from this flat every day. Can you continue the poem about the view from a flat that the writer mentioned?</s>
# <|assistant|>
# The view from this flat is ever-changing,
# A canvas painted with the hues of the sky.
# Some days it's an explosion of fiery colors,
# Other times it's a serene, peaceful sigh.
#
# From here, I can see the world moving,
# People rushing to and fro in a blur.
# Cars weaving through the crowded streets,
# A constant hum that will never purr.
#
# But amidst the chaos and flurry,
# The sun rises and sets like a guiding light.
# Stitching headlights through the scene,
# A reminder that the day will soon take flight.
#
# And though this world may spin and spin,
# The view from this flat is a constant friend.
# A haven for quiet contemplation,
# A place where thoughts can begin and end.</s>
# <|user|>
# Can you find any other instances of the writer using descriptive language to portray the view from the flat?</s>
# <|assistant|>
# Certainly! Here are some other examples of descriptive language used by the writer to portray the view from the flat:
#
# - "A canvas painted with the hues of the sky"
# - "An explosion of fiery colors"
# - "A serene, peaceful sigh"
# - "People rushing to and fro in a blur"
# - "Cars weaving through the crowded streets"
# - "A constant hum that will never purr"
# - "The sun rises and sets like a guiding light"
# - "A reminder that the day will soon take flight"
# - "A haven for quiet contemplation"
# - "A place where thoughts can begin and end"
#
# These descriptions create a vivid picture of the scene outside the writer's flat, using language that appeals to the senses and helps the reader visualize the setting.</s>
# <|user|>
# Can you suggest any other descriptive words or phrases the writer could use to convey the view from their flat?</s>
# <|assistant|>
# Certainly! Here are some other descriptive words or phrases the writer could use to convey the view from their flat:
#
# - A sea of buildings and rooftops stretch out before me.
# - The cityscape hums with the energy of life.
# - The light bounces off the glass and steel, casting a shimmering effect.
# - The skyline is etched in pale pink and orange hues.
# - The billowing clouds cast diffuse light on the rooftops.
# - The city moves and shifts like a living organism at street level.
# - The trees sway gently, a lulling contrast to the urban chaos below.
# - The city glitters like a bedazzled lover at dusk.
# - The sky's rich blues and bright oranges create a striking contrast against the gray cement.
# - The city brightens as the dawn breaks - a colorful symphony that awakens the day.
#
# These words and phrases can help the writer create a sense of place and atmosphere for the reader and transport them to the writer's urban viewpoint.</s>
# <|user|>
# Can you suggest any other ways the writer could describe the sunrise from their flat?</s>
# <|assistant|>
# Certainly! Here are some other ways the writer could describe the sunrise from their flat:
#
# - The sun rises like a glowing ember in the sky, slowly gaining strength and warmth as it ascends.
# - The colors of the sunrise bleed across the horizon like watercolors painted across a canvas.
# - The sky transforms from a deep, dark blue to a fiery orange and pink as the sun peeks over the edge of the world.
# - The city's silhouette emerges in soft relief against the brightening sky.
# - The slow reveal of the sun's warmth and light is like a kiss on the cheek of a sleeping world.
# - As the sun rises higher, its light reflects off the buildings and dances on the pavement below.
# - The sunrise is a peaceful prelude to the urban frenzy that will soon ensue.
# - Each morning, the sunrise is a reminder that life begins anew, full of promise and potential.
# - The stillness of dawn is slowly broken by the sounds of cars and people, but for now, the world is quiet and peaceful.
# - The sunrise is a daily reminder that no matter what happens in the day ahead, the sun will always rise again tomorrow.</s>
#
# Sample 66 of the processed training set:
#
# <|system|>
# </s>
# <|user|>
# Please write a comprehensive and step-by-step how-to guide explaining the process of installing a window, including tips for measuring and cutting the opening, types of sealant to use, tools needed, and safety precautions to take. The guide should be written in clear and concise language and contain diagrams or images to aid in understanding the steps.</s>
# <|assistant|>
# Installing a window can be a big and rewarding DIY project. A new window can improve energy efficiency, improve the look of your home, and add value to your property. Follow these steps for a successful window installation.
#
# Materials:
# - Measuring tape
# - Circular saw
# - Level
# - Hammer
# - Pry bar
# - Caulk gun
# - Utility knife
# - Window
# - Window sill foam
# - Screws and shims
# - Exterior sealant
# - Interior trim
#
# Step 1: Measure the Opening
# Make sure to measure the rough opening, not the existing window. Measure the width and height of the opening at three points (top, middle, and bottom) and use the smallest measurement as the width and the shortest measurement as the height. Make sure to allow for additional space for shims and insulation.
#
# Step 2: Cut the Opening
# Start by removing the existing window and placing it aside. Use a saw and a reciprocating saw blade to cut the opening for the new window. Use caution when cutting and wear protective eyewear and gloves.
#
# Step 3: Install the Window
# Have a helper on the outside of the window hold the new window in place while you level it from the inside. Place shims at each corner and at least one in the center of each side. Make sure the window is level and plumb. Screw each corner of the window frame to the wall, then check the window again for level and plumb.
#
# Step 4: Insulate the Window
# Once the window is in place, use foam insulation to fill any gaps between the window frame and the rough opening. This will help improve energy efficiency and reduce drafts.
#
# Step 5: Seal the Window
# Use a high-quality exterior sealant to seal the gap between the window frame and the exterior wall. Make sure to follow the manufacturer's instructions for using the sealant. Apply the sealant around the entire perimeter of the window.
#
# Step 6: Finish the Window
# Install interior trim to cover any gaps between the window and the interior wall. Use caulk to seal around the interior trim.
#
# Safety Precautions:
#
# - Wear protective eyewear and gloves when using power tools.
# - Use a stable ladder or scaffolding when working at heights.
# - Work with a partner to lift and hold the window in place.
# - Follow all manufacturer's instructions for using tools and materials.
#
# By following these steps and taking proper precautions, you can successfully install a new window in your home. Remember to take your time and be patient, and you'll have a beautiful and functional new window in no time!</s>
# <|user|>
# Is it possible to have more detailed information on the types of sealants that can be used for exterior sealing? Also, can you suggest some safety precautions specific to sealing the window?</s>
# <|assistant|>
# Yes, of course. Here is more information on the types of sealants commonly used for exterior sealing of windows:
#
# 1. Silicone sealants: These sealants are moisture-resistant and UV-resistant, making them an excellent choice for use on the exterior of windows. They also remain flexible over time, allowing the seal to withstand expansion and contraction of the window frame due to temperature changes. 2. Polyurethane sealants: These sealants are extremely durable and have excellent adhesion. They are great for use in areas where water and weather resistance is essential, such as on the exterior of windows. 3. Butyl tape: Butyl tape is a sticky, rubber-like adhesive tape that is suitable for sealing windows. It is easy to use, creates a durable seal, and is generally used for sealing around the perimeter of the window. 4. Acrylic sealants: Acrylic sealants are a water-based sealant that forms a flexible seal when dry. They are suitable for use on the exterior of windows that are not exposed to direct sunlight or temperature fluctuations. When it comes to safety precautions for sealing the window, here are a few additional tips:
#
# 1. Wear gloves and protective eyewear to protect your skin and eyes from any chemicals in the sealant. 2. Work in a well-ventilated area to avoid inhaling any fumes from the sealant. 3. Follow the manufacturer's instructions for applying the sealant, as different sealants may require different application methods. 4. Be careful not to overapply the sealant, as excess sealant can be unsightly and difficult to remove. 5. Make sure the surface you're applying the sealant to is clean and dry before applying the sealant. This will help the sealant adhere properly. By taking these safety precautions, you can ensure a successful and safe window installation project.</s>
# <|user|>
# Thank you for the additional information on sealants and safety precautions. Can you provide some tips on how to ensure that the window is properly sealed and insulated after installation? Also, could you recommend some reputable manufacturers of window sealant and insulation materials?</s>
# <|assistant|>
# Sure, here are some tips to ensure the window is properly sealed and insulated after installation:
#
# 1. Check for any visible gaps: Walk around the perimeter of the window and check for any visible gaps between the window and the wall. These gaps should be filled with sealant or insulation.
#
# 2. Use a thermal camera: You can use a handheld thermal camera to check for any areas of air leakage. These cameras detect changes in temperature and can show you where hot or cold air is entering or leaving your home.
#
# 3. Check for drafts: On a windy day, hold a piece of tissue paper or a lit candle near the window to check for any drafts. If you notice any drafts, this could be a sign that the window is not properly sealed.
#
# 4. Test the window for air leakage: Use the "smoke stick" test to check for air leakage. Hold a smoke stick near the window while it's closed, and look for any areas where the smoke is drawn into the room, as this indicates air leakage.
#
# As for reputable manufacturers of window sealant and insulation materials, here are a few to consider:
#
# 1. 3M: A well-known manufacturer of a variety of adhesives, sealants, and insulation materials, including silicone and polyurethane sealants.
#
# 2. Dow Corning: Another top manufacturer of silicone sealants for use on windows and other exterior applications.
#
# 3. Owens Corning: A leading manufacturer of insulation materials for use around windows and throughout the home.
#
# 4. Great Stuff: A popular brand of expanding foam insulation for sealing gaps and cracks around windows.
#
# When selecting sealant and insulation materials, be sure to read product labels and choose those that are appropriate for your specific project and needs.</s>
# <|user|>
# Thank you for the detailed information on sealing and insulating after window installation. Can you suggest some specific products or materials from the recommended manufacturers that you mentioned? Also, can you provide some tips on how to properly apply the sealant and insulation, particularly for someone who is doing this for the first time?</s>
# <|assistant|>
# Yes, here are some specific product recommendations from the mentioned manufacturers:
#
# 3M:
# - 3M Fire Block Foam: Expanding foam that fills gaps and cracks to block fire, smoke, and toxic gases from spreading.
# - 3M Super Silicone Sealant: A high-quality silicone sealant that seals and bonds a variety of materials and surfaces.
#
# Dow Corning:
# - Dow Corning 791: A high-performance silicone sealant that can be used on glass, aluminum, and other construction materials.
# - Dow Corning Great Stuff PRO Window and Door: An insulating foam sealant designed specifically for use around windows and doors to create an airtight seal.
#
# Owens Corning:
# - Fiberglass Insulation: Owens Corning offers a variety of fiberglass insulation products for different applications, including batts, rolls, and loose-fill.
# - Foamular Insulation: Owens Corning offers Foamular Insulation, which is a rigid insulation made from extruded polystyrene foam.
#
# Great Stuff:
# - Great Stuff Window & Door: An insulating foam sealant designed for use around windows and doors to seal gaps and cracks.
# - Great Stuff Gaps and Cracks: An insulating foam sealant that can be used to fill gaps and cracks throughout the home.
#
# When it comes to applying sealant and insulation for the first time, here are some tips to follow:
#
# 1. Read the product label and follow the manufacturer's instructions carefully.
#
# 2. Wear disposable gloves to protect your skin from the sealant or insulation.
#
# 3. Use a caulk gun for sealants and an expanding foam nozzle for insulation.
#
# 4. Apply the sealant or insulation in a continuous bead or layer, making sure to fill all gaps and cracks completely.
#
# 5. Use a tool, such as a caulk smoothing tool or putty knife, to smooth the sealant or insulation to create a neat finish.
#
# 6. Allow the sealant or insulation to dry or cure according to the manufacturer's instructions, which may take several hours or days depending on the product.
#
# By following these tips, you can ensure a successful application of sealant and insulation around your windows.</s>
#
# Sample 11 of the processed training set:
#
# <|system|>
# </s>
# <|user|>
# How did the Spanish conquest of the Low Countries in the 16th century impact European politics and culture?</s>
# <|assistant|>
# The Spanish conquest of the Low Countries in the 16th century had a significant impact on European politics and culture. Here are some of the impacts:
#
# 1. Religious conflicts: The Low Countries were a major center of Protestantism, and Spanish rule led to religious conflicts between Catholics and Protestants. This led to the Eighty Years' War (1568-1648) which was fought between the Protestant Dutch and the Spanish Catholics.
#
# 2. Rise of Dutch power: The Spanish conquest of the Low Countries led to the rise of Dutch power in Europe. The Dutch fought against the Spanish and eventually gained independence in 1648. The Dutch Republic emerged as a major power in Europe, with significant influence on trade, politics, and culture.
#
# 3. Cultural exchange: The Spanish conquest of the Low Countries led to a cultural exchange between the Spanish and the Dutch. The Dutch were exposed to Spanish art, literature, and architecture, which had a significant impact on the Dutch Golden Age.
#
# 4. Birth of modern international politics: The Spanish conquest of the Low Countries was one of the first instances of modern international politics. The conflict involved various European powers, including France, England, and Germany, and led to a shift in the balance of power in Europe.
#
# 5. Spread of colonialism: The Spanish conquest of the Low Countries also led to the spread of colonialism. After gaining independence, the Dutch established a large colonial empire in Asia and the Americas, which had a significant impact on trade and culture.</s>
# <|user|>
# Wow, it's interesting how one event had such a ripple effect. Did the Spanish conquest have any lasting effects on the Low Countries themselves?</s>
# <|assistant|>
# Yes, the Spanish conquest had several lasting effects on the Low Countries:
#
# 1. Economic decline: The Spanish conquest led to a decline in the economy of the Low Countries. The Spanish imposed heavy taxes on the Dutch, and many Dutch merchants and traders moved to other countries. This led to a decline in trade and commerce, which had been the backbone of the Dutch economy.
#
# 2. Cultural suppression: The Spanish tried to suppress Dutch language and culture, and promoted Catholicism over Protestantism. This led to a sense of resentment among the Dutch towards Spanish rule and a desire for independence.
#
# 3. Political fragmentation: The Spanish conquest led to the fragmentation of the Low Countries into different regions, each with its own ruler. This created a sense of disunity among the Dutch and made it easier for the Spanish to control them.
#
# 4. Military innovations: The Spanish conquest led to the Dutch developing new military innovations to resist Spanish oppression. This included the development of new weapons, tactics, and fortifications, which later contributed to the Dutch military successes in their battles for independence.
#
# Overall, the Spanish conquest had a significant impact on the culture, economy, and politics of the Low Countries, and played a major role in shaping their future.</s>
# <|user|>
# It's amazing how history can have such a lasting impact on a country. Do you think the Dutch culture and language would be different today if the Spanish hadn't conquered the Low Countries?</s>
# <|assistant|>
# It's difficult to speculate on what might have happened had the Spanish not conquered the Low Countries. However, it is likely that Dutch culture and language would have developed differently under different historical circumstances, depending on which countries or empires came into contact with the Dutch.
#
# It's possible that without Spanish rule, the Low Countries would have remained a Protestant stronghold and developed closer ties with countries like England and Germany, rather than Catholic Spain. This might have influenced the development of Dutch culture and language in ways that are difficult to predict.
#
# In any event, the Spanish conquest of the Low Countries did have a significant impact on Dutch culture and language, as it led to a sense of resistance and a desire for independence that helped shape the Dutch national identity. The suppression of Dutch culture and language by the Spanish also contributed to the development of a distinct Dutch language and literature, which would have been less likely to emerge if the Dutch had not been oppressed by an outside power.</s>

# %% [markdown]
# ### Define the model arguments

# %%
from transformers import BitsAndBytesConfig
import torch

# specify how to quantize the model
quantization_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.bfloat16,
)
device_map = {"": torch.cuda.current_device()} if torch.cuda.is_available() else None

model_kwargs = dict(
    # attn_implementation="flash_attention_2", # set this to True if your GPU supports it (Flash Attention drastically speeds up model computations)
    torch_dtype="auto",
    use_cache=False, # set to False as we're going to use gradient checkpointing
    device_map=device_map,
    quantization_config=quantization_config,
)

# %%
from trl import SFTTrainer
from peft import LoraConfig
from transformers import TrainingArguments

# path where the Trainer will save its checkpoints and logs
output_dir = 'data/zephyr-7b-sft-lora'

# based on config
training_args = TrainingArguments(
    fp16=True, # specify bf16=True instead when training on GPUs that support bf16
    do_eval=True,
    evaluation_strategy="epoch",
    gradient_accumulation_steps=128,
    gradient_checkpointing=True,
    gradient_checkpointing_kwargs={"use_reentrant": False},
    learning_rate=2.0e-05,
    log_level="info",
    logging_steps=5,
    logging_strategy="steps",
    lr_scheduler_type="cosine",
    max_steps=-1,
    num_train_epochs=1,
    output_dir=output_dir,
    overwrite_output_dir=True,
    per_device_eval_batch_size=1, # originally set to 8
    per_device_train_batch_size=1, # originally set to 8
    # push_to_hub=True,
    # hub_model_id="zephyr-7b-sft-lora",
    # hub_strategy="every_save",
    # report_to="tensorboard",
    save_strategy="no",
    save_total_limit=None,
    seed=42,
)

# based on config
peft_config = LoraConfig(
        r=64,
        lora_alpha=16,
        lora_dropout=0.1,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules=["q_proj", "k_proj", "v_proj", "o_proj"],
)

trainer = SFTTrainer(
        model=model_id,
        model_init_kwargs=model_kwargs,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        dataset_text_field="text",
        tokenizer=tokenizer,
        packing=True,
        peft_config=peft_config,
        max_seq_length=tokenizer.model_max_length,
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:166: UserWarning: You passed a model_id to the SFTTrainer. This will automatically create an `AutoModelForCausalLM` or a `PeftModel` (if you passed a `peft_config`) for you.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Generating train split: 0 examples [00:00, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (3400 > 2048). Running this sequence through the model will result in indexing errors
# Generating train split: 0 examples [00:00, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:318: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# Using auto half precision backend

# %%
# Train the model
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 67
#   Num Epochs = 1
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 128
#   Gradient Accumulation steps = 128
#   Total optimization steps = 1
#   Number of trainable parameters = 54,525,952
